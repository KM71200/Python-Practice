# %% [markdown]
# #**PYTHON LAB FILE**
#
# Sap Id: 590025695
#
# Name: KARMANYA MALETHA
#
# Batch:11
#
# Courese: BTech CSE

# %% [markdown]
# ##EXPERIMENT-2: Conditional Statements
# (LAB-2)

# %% [markdown]
# **Q1) Check whether the given number is divisible by 3 and 5 both.**

# %%
n = int(input("Enter no:"))
if n%15 == 0:
    print(f"{n} is divisible by 3 and 5")
else:
    print(f"{n} is not divisible by 3 and 5")
# Out:
# Enter no:60
# 60 is divisible by 3 and 5

# %% [markdown]
# **Q2) Check whether a given number is multiple of five or not.**

# %%
a = int(input("Enter a number:"))
if a%5 == 0:
  print(f"{a} is a multiple of 5")
else:
  print(f"{a} is not a multiple of 5")
# Out:
# Enter a number:50
# 50 is a multiple of 5

# %% [markdown]
# **Q3) Find the greatest among the two numbers. If numbers are equal than print
# “numbers are equal”.**

# %%
a = int(input("Enter first number:"))
b = int(input("Enter second number:"))
c = int(input("Enter third number:"))
if a==b or b==c or a==c :
  print("Please Enter different values")

else:
    g = max(a,b,c)
    print(f"{g} is the greatest")
# Out:
# Enter first number:2
# Enter second number:16
# Enter third number:10
# 16 is the greatest

# %% [markdown]
# **Q4) Find the greatest among three numbers assuming no two values are same.**

# %%
a = int(input("Enter first number:"))
b = int(input("Enter second number:"))
c = int(input("Enter third number:"))
if a==b==c :
  print("Please Enter different values")
g = max(a,b,c)
print(f"{g} is the greatest")
# Out:
# Enter first number:5
# Enter second number:4
# Enter third number:10
# 10 is the greatest

# %% [markdown]
# **Q5) Check whether the quadratic equation has real roots or imaginary roots.
# Display the roots.**

# %%
import math as m
a = float(input("Enter value of a:"))
b = float(input("Enter value of b:"))
c = float(input("Enter value of c:"))

D = b**2 - 4*a*c

if D > 0:
  r1 = (-b + m.sqrt(D))/(2*a)
  r2= (-b - m.sqrt(D))/(2*a)
  print("Roots are real and distinct")
  print(f"Roots are:{r1,r2}")

elif D==0:
  r1 = -b/(2*a)
  print("Roots are equal:")
  print(f"Roots are:{r1}")

else:
  real = -b/(2*a)
  img= m.sqrt(-D)/(2*a)
  print("Roots are complex")
  print(f"Roots are:{real} + {img:.2f}i, {real} - {img:.2f}i")
# Out:
# Enter value of a:1
# Enter value of b:2
# Enter value of c:5
# Roots are complex
# Roots are:-1.0 + 2.00i, -1.0 - 2.00i

# %% [markdown]
# **Q6) Find whether a given year is a leap year or not.**

# %%
n = int(input("Enter year:"))
if n%400 ==0 or n%4 == 0 and n%100 !=0:
  print(f"{n} is a leap year")
else:
  print(f"{n} is not a leap year")
# Out:
# Enter year:1900
# 1900 is not a leap year

# %% [markdown]
# **Q7) Write a program which takes any date as input and display next date of the
# calendar**

# %%
d = int(input("Enter Day:"))
m = int(input("Enter Month:"))
y = int(input("Enter Year:"))
flag = True

if m<1 or m>12:
    flag = False

if flag:
    if m == 2:
        if y%400 == 0 or y%4 == 0 and y%100 != 0 :
            max_day = 29
        else:
            max_day = 28

    elif m in [1,3,5,7,8,10,12]:
            max_day = 31

    else:
        max_day = 30


if flag:
    if d < 1 or d > max_day:
        flag = False

    if d < max_day:
        d += 1

    else:
        d = 1
        if m == 12:
            m = 1
            y += 1

        else:
            m += 1


if flag:
    print(f"Next date:{d}/{m}/{y}")

else:
    print("Enter a valid date")
# Out:
# Enter Day:29
# Enter Month:2
# Enter Year:2024
# Next date:1/3/2024

# %% [markdown]
# **8) Print the grade sheet of a student for the given range of cgpa. Scan marks of
# five subjects and calculate the percentage**

# %%
name = input("Enter your name: ")
roll = int(input("Enter your roll number: "))
sap = int(input("Enter your SAP ID: "))
sem = int(input("Enter current semester:"))
course = input("Enter the course opted for:")

pds = float(input("Enter marks of PDS: "))
py = float(input("Enter marks of Python: "))
chm = float(input("Enter marks of Chemistry: "))
eng = float(input("Enter marks of English: "))
phy = float(input("Enter marks of Physics: "))

print(f"Name: {name}")
print(f"Roll no.: {roll} SAPID: {sap}\t")
print(f"Sem: {sem}\t Course: {course}")
print(f"""   Subject              Marks
      PDS                {pds}
      Python             {py}
      Chemistry          {chm}
      English            {eng}
      Physics            {phy}""")

percentage = (pds + py + chm + eng + phy)/5
cgpa = percentage / 10

print(f"Percentage:{percentage}%")
print(f"CGPA:{cgpa}")

if cgpa >= 0 and cgpa <=3.4:
    print("Grade:F")

elif cgpa >= 3.5 and cgpa <= 5:
    print("Grade:C+")

elif cgpa >= 5.1 and cgpa <=6:
    print("Grade:B")

elif cgpa >= 6.1 and cgpa <=7:
    print("Grade:B+")

elif cgpa >= 7.1 and cgpa <=8:
    print("Grade:A")

elif cgpa >= 8.1 and cgpa <=9:
    print("Grade:A+")

elif cgpa >=9.1 and cgpa <=10:
    print("Grade:O")
# Out:
# Enter your name: Karmanya Maletha
# Enter your roll number: 12345678
# Enter your SAP ID: 590025695
# Enter current semester:2
# Enter the course opted for:Btech
# Enter marks of PDS: 91
# Enter marks of Python: 96
# Enter marks of Chemistry: 88
# Enter marks of English: 85
# Enter marks of Physics: 90
# Name: Karmanya Maletha
# Roll no.: 12345678 SAPID: 590025695
# Sem: 2	 Course: Btech
#    Subject              Marks
#       PDS                91.0
#       Python             96.0
#       Chemistry          88.0
#       English            85.0
#       Physics            90.0
# Percentage:90.0%
# CGPA:9.0
# Grade:A+
